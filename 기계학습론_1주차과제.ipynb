# %% [markdown]
# <a href="https://colab.research.google.com/github/seungmin-son/ML_Practice/blob/main/%EA%B8%B0%EA%B3%84%ED%95%99%EC%8A%B5%EB%A1%A0_1%EC%A3%BC%EC%B0%A8%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1주차 과제

# %% [markdown]
# ### 1번

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(6, 5), columns=['col1', 'col2', 'col3', 'col4', 'col5'])

# %%
df
# Out:
#        col1      col2      col3      col4      col5
# 0 -1.001661  1.285879  0.683902 -1.349673 -1.375616
# 1 -1.188177  0.062387  0.982499  0.290923  0.695011
# 2 -1.087841 -0.582953  0.605737  0.335317  1.393428
# 3  0.009741 -0.239273 -0.731125  2.445750 -0.851180
# 4 -0.358660 -0.568532  0.240191  2.734265  0.298173
# 5 -0.579504  2.267073 -0.257198 -1.307715 -0.387083

# %%
df['col6'] = df['col1'] + df['col3']

# %%
df
# Out:
#        col1      col2      col3      col4      col5      col6
# 0 -1.001661  1.285879  0.683902 -1.349673 -1.375616 -0.317759
# 1 -1.188177  0.062387  0.982499  0.290923  0.695011 -0.205678
# 2 -1.087841 -0.582953  0.605737  0.335317  1.393428 -0.482104
# 3  0.009741 -0.239273 -0.731125  2.445750 -0.851180 -0.721384
# 4 -0.358660 -0.568532  0.240191  2.734265  0.298173 -0.118469
# 5 -0.579504  2.267073 -0.257198 -1.307715 -0.387083 -0.836702

# %% [markdown]
# ### 2번

# %%
df[df < 0.3] = np.nan
df
# Out:
#    col1      col2      col3      col4      col5  col6
# 0   NaN  1.285879  0.683902       NaN       NaN   NaN
# 1   NaN       NaN  0.982499       NaN  0.695011   NaN
# 2   NaN       NaN  0.605737  0.335317  1.393428   NaN
# 3   NaN       NaN       NaN  2.445750       NaN   NaN
# 4   NaN       NaN       NaN  2.734265       NaN   NaN
# 5   NaN  2.267073       NaN       NaN       NaN   NaN
